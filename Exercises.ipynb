# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as pnp
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/guipsamora/pandas_exercises/blob/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %%
url= "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv"

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df= pd.read_csv(url,sep=',')
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
df.columns
# Out:
# Index([u'school', u'sex', u'age', u'address', u'famsize', u'Pstatus', u'Medu',
#        u'Fedu', u'Mjob', u'Fjob', u'reason', u'guardian', u'traveltime',
#        u'studytime', u'failures', u'schoolsup', u'famsup', u'paid',
#        u'activities', u'nursery', u'higher', u'internet', u'romantic',
#        u'famrel', u'freetime', u'goout', u'Dalc', u'Walc', u'health',
#        u'absences', u'G1', u'G2', u'G3'],
#       dtype='object')

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df_sliced=df.loc[:,"school":"guardian"]
df_sliced
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
#lambda que recibe u parametro y lo combierte en upper
cap= lambda x: x.upper()
df_sliced['Mjob'].apply(cap)
# Out:
# 0       AT_HOME
# 1       AT_HOME
# 2       AT_HOME
# 3        HEALTH
# 4         OTHER
# 5      SERVICES
# 6         OTHER
# 7         OTHER
# 8      SERVICES
# 9         OTHER
# 10      TEACHER
# 11     SERVICES
# 12       HEALTH
# 13      TEACHER
# 14        OTHER
# 15       HEALTH
# 16     SERVICES
# 17        OTHER
# 18     SERVICES
# 19       HEALTH
# 20      TEACHER
# 21       HEALTH
# 22      TEACHER
# 23        OTHER
# 24     SERVICES
# 25     SERVICES
# 26        OTHER
# 27       HEALTH
# 28     SERVICES
# 29      TEACHER
#          ...
# 365     AT_HOME
# 366     TEACHER
# 367       OTHER
# 368     AT_HOME
# 369       OTHER
# 370    SERVICES
# 371     AT_HOME
# 372       OTHER
# 373       OTHER
# 374       OTHER
# 375       OTHER
# 376      HEALTH
# 377     TEACHER
# 378       OTHER
# 379     AT_HOME
# 380     TEACHER
# 381       OTHER
# 382       OTHER
# 383       OTHER
# 384       OTHER
# 385     AT_HOME
# 386     TEACHER
# 387    SERVICES
# 388     TEACHER
# ...

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df_sliced.Mjob.apply(cap)
df_sliced.Fjob.apply(cap)
# Out:
# 0       TEACHER
# 1         OTHER
# 2         OTHER
# 3      SERVICES
# 4         OTHER
# 5         OTHER
# 6         OTHER
# 7       TEACHER
# 8         OTHER
# 9         OTHER
# 10       HEALTH
# 11        OTHER
# 12     SERVICES
# 13        OTHER
# 14        OTHER
# 15        OTHER
# 16     SERVICES
# 17        OTHER
# 18     SERVICES
# 19        OTHER
# 20        OTHER
# 21       HEALTH
# 22        OTHER
# 23        OTHER
# 24       HEALTH
# 25     SERVICES
# 26        OTHER
# 27     SERVICES
# 28        OTHER
# 29      TEACHER
#          ...
# 365       OTHER
# 366    SERVICES
# 367    SERVICES
# 368    SERVICES
# 369     TEACHER
# 370    SERVICES
# 371    SERVICES
# 372     AT_HOME
# 373       OTHER
# 374       OTHER
# 375       OTHER
# 376       OTHER
# 377    SERVICES
# 378       OTHER
# 379       OTHER
# 380     TEACHER
# 381       OTHER
# 382    SERVICES
# 383    SERVICES
# 384       OTHER
# 385       OTHER
# 386     AT_HOME
# 387       OTHER
# 388    SERVICES
# ...

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df_sliced.tail(5)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 390  course    other
# 391  course   mother
# 392  course    other
# 393  course   mother
# 394  course   father

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
df_sliced['Mjob']=df_sliced.Mjob.apply(cap)
df_sliced.['Fjob'].apply(cap)

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
df_sliced['legal_drinker'] = df['Pstatus'].str.contains('A')
df_sliced
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
majority= lambda x: True if x>19 else False

# %%
df_sliced['Majority']= df_sliced['age'].apply(majority)
df_sliced
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
def multbyten(x):
    if type(x) is str:
        return x
    elif type(x) is np.int64
